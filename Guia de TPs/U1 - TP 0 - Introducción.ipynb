# %% [markdown]
# ## TP 0, Computación III
# Carrera Física Aplicada, INSPT UTN<br>
# Daiana Dominikow.

# %% [markdown]
# ### Introducción Python

# %% [markdown]
# 1) Con un loop imprimir números naturales menores a 10

# %% [markdown]
# 2) Función para convertir de °F a °C <br>
# $ C = (F-32)\frac{5}{9}$

# %% [markdown]
# 2) Función para convertir de °F a °C <br>
# $ C = (F-32)\frac{5}{9}$

# %% [markdown]
# 3) Función que recibe tiempo y velocidad y devuelve la posición de un objeto en tiro vertical.
